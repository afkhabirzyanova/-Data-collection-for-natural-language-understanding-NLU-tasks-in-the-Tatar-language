# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install "optimum-onnx[onnxruntime_gpu]"@git+https://github.com/huggingface/optimum-onnx.git
# !pip install sentencepiece pyarrow regex huggingface-hub
# Out:
# Collecting optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git (from optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git)
#   Cloning https://github.com/huggingface/optimum-onnx.git to /tmp/pip-install-h5ede1om/optimum-onnx_4cc625da29604f7b9e991dc58e9d0d53
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/optimum-onnx.git /tmp/pip-install-h5ede1om/optimum-onnx_4cc625da29604f7b9e991dc58e9d0d53
#   Resolved https://github.com/huggingface/optimum-onnx.git to commit 671b84f78a244594dd21cb1a8a1f7abb8961ea60
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting optimum@ git+https://github.com/huggingface/optimum (from optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git)
#   Cloning https://github.com/huggingface/optimum to /tmp/pip-install-h5ede1om/optimum_820df29b3b5b451b9fccba78e0e00626
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/optimum /tmp/pip-install-h5ede1om/optimum_820df29b3b5b451b9fccba78e0e00626
#   Resolved https://github.com/huggingface/optimum to commit a813c95ac088c401547fe15e7a68ac5c6f00f9a7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting transformers<4.56.0,>=4.36 (from optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git)
#   Downloading transformers-4.55.4-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.5 MB/s eta 0:00:00
# Collecting onnx (from optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git)
#   Downloading onnx-1.19.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.0 kB)
# Collecting onnxruntime-gpu>=1.18.0 (from optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git)
#   Downloading onnxruntime_gpu-1.23.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.2 kB)
# Collecting coloredlogs (from onnxruntime-gpu>=1.18.0->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu>=1.18.0->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu>=1.18.0->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu>=1.18.0->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu>=1.18.0->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu>=1.18.0->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (1.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (0.35.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (2.32.4)
# Collecting tokenizers<0.22,>=0.21 (from transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git)
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (4.67.1)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (4.15.0)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (from onnx->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (0.5.3)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.12/dist-packages (from optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (2.8.0+cu126)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (1.1.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (75.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime-gpu>=1.18.0->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (1.3.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu>=1.18.0->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.56.0,>=4.36->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11->optimum@ git+https://github.com/huggingface/optimum->optimum-onnx@ git+https://github.com/huggingface/optimum-onnx.git->optimum-onnx[onnxruntime_gpu]@ git+https://github.com/huggingface/optimum-onnx.git) (3.0.2)
# Downloading onnxruntime_gpu-1.23.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (300.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.5/300.5 MB 5.0 MB/s eta 0:00:00
# Downloading transformers-4.55.4-py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 80.5 MB/s eta 0:00:00
# Downloading onnx-1.19.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 55.6 MB/s eta 0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 74.1 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.5 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.6 MB/s eta 0:00:00
# Building wheels for collected packages: optimum-onnx, optimum
#   Building wheel for optimum-onnx (pyproject.toml) ... done
#   Created wheel for optimum-onnx: filename=optimum_onnx-0.0.0.dev0-py3-none-any.whl size=191290 sha256=bfebc399f3f4be5c42fdc82ba3ed78f67ac59b0aef041d0143f0e4c761b06ad1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x_7uh7tf/wheels/5f/97/89/c6a47604a20e44989d02639a1786dba247248111ec42335914
#   Building wheel for optimum (pyproject.toml) ... done
#   Created wheel for optimum: filename=optimum-2.0.0.dev0-py3-none-any.whl size=164960 sha256=b4a3b604dfe10690ade09d6ab33f00bdc8c38bd390e31a3842434f1ff65f3238
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x_7uh7tf/wheels/4a/c7/72/f0a71f75076bac382ef01cf2f8ae694d709b39641555fd36e0
# Successfully built optimum-onnx optimum
# Installing collected packages: humanfriendly, onnx, coloredlogs, tokenizers, onnxruntime-gpu, transformers, optimum, optimum-onnx
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.0
#     Uninstalling tokenizers-0.22.0:
#       Successfully uninstalled tokenizers-0.22.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.1
#     Uninstalling transformers-4.56.1:
#       Successfully uninstalled transformers-4.56.1
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnx-1.19.0 onnxruntime-gpu-1.23.0 optimum-2.0.0.dev0 optimum-onnx-0.0.0.dev0 tokenizers-0.21.4 transformers-4.55.4
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (18.1.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (2024.11.6)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (0.35.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub) (2025.8.3)

# %% [markdown]
# # Код из репозитория [Söyle](https://github.com/IS2AI/Soyle?tab=readme-ov-file)

# %%
# Import required modules
from optimum.onnxruntime import ORTModelForSpeechSeq2Seq
from transformers import pipeline, AutoTokenizer, AutoFeatureExtractor, AutoModelForSpeechSeq2Seq

# Set parameters
model_id = 'dhcppc0/soyle_onnx'
audio_file = "/content/drive/MyDrive/Курсовая_3_курс/Голосовые/Женщина_20"
# audio_file = "test_253.wav"

lang_id = "<|tt|>"

# Load the pre-trained model with GPU support (or change to "CPUExecutionProvider" if GPU is not available)
model = ORTModelForSpeechSeq2Seq.from_pretrained(model_id, provider="CPUExecutionProvider")

# Load the tokenizer and feature_extractor
tokenizer = AutoTokenizer.from_pretrained(model_id)
feature_extractor = AutoFeatureExtractor.from_pretrained(model_id)

# %%
# Create a pipeline for automatic speech recognition
pipe = pipeline("automatic-speech-recognition", model=model, tokenizer=tokenizer, feature_extractor=feature_extractor)

# Run inference (larger batch_size yields faster recognition, but may reduce quality)
output = pipe(audio_file, batch_size=4, generate_kwargs = {"language":lang_id})['text']
print(output)

# %% [markdown]
# # Адаптация кода под мои файлы

# %%
import os

audio_dir = "/content/drive/MyDrive/Курсовая_3_курс/Голосовые/Мужчина_41"   # поправь путь если нужно
wav_files = [os.path.join(audio_dir, f) for f in os.listdir(audio_dir) if f.endswith(".wav")]

print(f"Найдено {len(wav_files)} wav-файлов")
# Out:
# Найдено 50 wav-файлов

# %%
from optimum.onnxruntime import ORTModelForSpeechSeq2Seq
from transformers import pipeline, AutoTokenizer, AutoFeatureExtractor

model_id = "dhcppc0/soyle_onnx"
lang_id = "<|tt|>"

model = ORTModelForSpeechSeq2Seq.from_pretrained(model_id, provider="CUDAExecutionProvider")

tokenizer = AutoTokenizer.from_pretrained(model_id)
feature_extractor = AutoFeatureExtractor.from_pretrained(model_id)

pipe = pipeline("automatic-speech-recognition",
                model=model,
                tokenizer=tokenizer,
                feature_extractor=feature_extractor)
# Out:
# Multiple distributions found for package optimum. Picked distribution: optimum-onnx
# /usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/registration.py:162: OnnxExporterWarning: Symbolic function 'aten::scaled_dot_product_attention' already registered for opset 14. Replacing the existing function with new function. This is unexpected. Please report it on https://github.com/pytorch/pytorch/issues.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# Could not find any ONNX files with standard file name decoder_model_merged.onnx, files found: [PosixPath('decoder_model.onnx'), PosixPath('decoder_with_past_model.onnx'), PosixPath('encoder_model.onnx')]. Please make sure to pass a `file_name` and/or `subfolder` argument to `from_pretrained` when loading an ONNX file with non-standard file names.
# ./encoder_model.onnx:   0%|          | 0.00/1.23G [00:00<?, ?B/s]
# ./decoder_model.onnx:   0%|          | 0.00/2.03G [00:00<?, ?B/s]
# ./decoder_with_past_model.onnx:   0%|          | 0.00/1.83G [00:00<?, ?B/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# Moving the following attributes in the config to the generation config: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50358, 50359, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
# tokenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/339 [00:00<?, ?B/s]
# Device set to use cuda:0

# %% [markdown]
# Смотрим сколько GPU осталось

# %%
import torch, time

def print_gpu_usage():
    if torch.cuda.is_available():
        free, total = torch.cuda.mem_get_info()
        used = (total - free) / 1024**3
        print(f"GPU Используется: {used:.2f} GB / {total/1024**3:.2f} GB")

# %%
output_path = "/content/drive/MyDrive/Курсовая_3_курс/Голосовые/soyle_results_9.txt"

with open(output_path, "w", encoding="utf-8") as f:
    for i, wav in enumerate(wav_files, 1):
        print(f"[{i}/{len(wav_files)}] Обработка: {os.path.basename(wav)}")
        print_gpu_usage()

        try:
            text = pipe(wav, batch_size=4, generate_kwargs={"language": lang_id})['text']
        except Exception as e:
            text = f"Ошибка при обработке: {e}"

        # Запись результата в файл
        f.write(f"# id: {os.path.basename(wav)}\n{text}\n\n")

        print("Распознанный текст:", text)
        print_gpu_usage()
        print("-" * 40)

print(f"Готово! Все результаты сохранены в {output_path}")
# Out:
# [1/50] Обработка: test_484.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: кичке биштә монда буран булачакмы
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [2/50] Обработка: test_485.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: ирландиянең 2015 елгы балалар евровидениесыннан минем евровидение җырлары җыентыгына өстә
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [3/50] Обработка: test_486.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: татар җырлары җыентыгына җырны өстә
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [4/50] Обработка: test_487.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: син миңа баш ваткыч тамашасын таба аласыңмы
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [5/50] Обработка: test_488.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: зинһар сәяхәт җыентыгына бу фирдүс тамаевның җырын өстә
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [6/50] Обработка: test_489.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: мин аларны уенчы фирдүс тамаевтан ишетергә телим
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [7/50] Обработка: test_490.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: шүрәле әкиятен биш йолдызга бәяли
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [8/50] Обработка: test_491.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: миңа башваткыч дип аталган телевизион тапшыруынны тап
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [9/50] Обработка: test_492.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: ак чәчәкләр китабын эзлә
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [10/50] Обработка: test_493.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: алмазга һәм айгөлгә 152 көннән соң ресторанда өстәл кирәк
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [11/50] Обработка: test_494.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: танылган ресторанны биш кешегә бронла
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [12/50] Обработка: test_495.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: казаннан ерак түгел каганат ателетында номерны борынлы
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [13/50] Обработка: test_496.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бу альбомны татар хитлары җыентыгына өстә
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [14/50] Обработка: test_497.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: көтелмәгән кунак телесериалын эзлә
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [15/50] Обработка: test_498.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: алты айдан соң казаннан ерак түгел иң яхшы ресторанда тугыз кешелек өстәл бронда
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [16/50] Обработка: test_499.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: миңа сан сити кинотеатрында фильмларны күрсәт
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [17/50] Обработка: test_500.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: аларның кампусында чара борынлы шул ук районда ресторанда
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [18/50] Обработка: test_1.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бөтен хәтерләтүләрне күрсәт
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [19/50] Обработка: test_6.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: чәршәмбе көнне миңа кул чатыры кирәкме
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [20/50] Обработка: test_4.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: минем хәтерләтүне бетер
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [21/50] Обработка: test_5.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: миңа бензин салырга искә төшер
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [22/50] Обработка: test_2.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: миңа свитер кирәкме
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [23/50] Обработка: test_3.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бүген сәгать ун алтыга хәтерләтүне өстә
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [24/50] Обработка: test_8.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: мәдинәнең туган көне турында искә төшер
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [25/50] Обработка: test_13.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бүген температура нинди
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [26/50] Обработка: test_10.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бөтен бу дип никларны күрсәт
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [27/50] Обработка: test_14.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: минем хәтерләтүне күрсәт
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [28/50] Обработка: test_11.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бүген яңгыр булырмы
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [29/50] Обработка: test_12.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: дилникларны иртәнге сигезгә куй
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [30/50] Обработка: test_7.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: биш минуттан соң минем будильнигымны кабатла
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [31/50] Обработка: test_15.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: барлык будильникларны күрсәт
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [32/50] Обработка: test_9.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: миңа бөтен хәтерләтүләрне күрсәт
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [33/50] Обработка: test_18.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бүген болытлымы
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [34/50] Обработка: test_16.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: миңа бен белән джорджия турында сөйләшергә искә төшер
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [35/50] Обработка: test_17.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: будильникны иртәнге бишкә куй
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [36/50] Обработка: test_20.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: иртәгә минем апама шалтыратырга искә төшер
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [37/50] Обработка: test_19.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бүген бездә ничә сантиметр кар явар
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [38/50] Обработка: test_21.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: будильникны туктат
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [39/50] Обработка: test_22.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бу атнада кызу булырмы
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [40/50] Обработка: test_24.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бүген кар явармы
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [41/50] Обработка: test_23.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: будильникны көндезге эчкә куй
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [42/50] Обработка: test_26.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: минем хәтерләүләрне күрсәтә
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [43/50] Обработка: test_25.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бөтен бутинникларны бетер
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [44/50] Обработка: test_30.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: син миңа будинникларны күрсәтә аласыңмы
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [45/50] Обработка: test_27.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: будильникка күпме вакыт калды
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [46/50] Обработка: test_28.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: минем нинди искә төшерүләрем бар
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [47/50] Обработка: test_32.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бүген кар явырмы
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [48/50] Обработка: test_31.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: бүген казанда буран булырмы
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [49/50] Обработка: test_33.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: барлык будинникларны күрсәт
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# [50/50] Обработка: test_29.wav
# GPU Используется: 10.55 GB / 14.74 GB
# Распознанный текст: будильникны көн саен иртәнге сигезгә куй
# GPU Используется: 10.55 GB / 14.74 GB
# ----------------------------------------
# Готово! Все результаты сохранены в /content/drive/MyDrive/Курсовая_3_курс/Голосовые/soyle_results_9.txt

# %%
text_dir = "/content/drive/MyDrive/Курсовая_3_курс/Голосовые/Текст"

txt_files = sorted([os.path.join(text_dir, f) for f in os.listdir(text_dir) if f.endswith(".txt")])

print(f"Найдено {len(txt_files)} файлов")

output_file = "/content/drive/MyDrive/Курсовая_3_курс/Голосовые/Текст/Объединенный_текст.txt"

with open(output_file, "w", encoding="utf-8") as outfile:
    for i, fname in enumerate(txt_files, 1):
        with open(fname, "r", encoding="utf-8") as infile:
            content = infile.read().strip()

            outfile.write(f"### Файл {os.path.basename(fname)}\n")
            outfile.write(content + "\n\n")

print(f"Файлы объединены в {output_file}")
# Out:
# Найдено 9 файлов
# Файлы объединены в /content/drive/MyDrive/Курсовая_3_курс/Голосовые/Текст/Объединенный_текст.txt

# %%
import re

text_dir = "/content/drive/MyDrive/Курсовая_3_курс/Голосовые/Текст"

output_file = "/content/drive/MyDrive/Курсовая_3_курс/Голосовые/Текст/Объединенный_по_id_2.txt"

txt_files = sorted([os.path.join(text_dir, f) for f in os.listdir(text_dir) if f.endswith(".txt")])

entries = []

for fname in txt_files:
    with open(fname, "r", encoding="utf-8") as f:
        content = f.read().strip()

        blocks = content.split("# id:")
        for block in blocks:
            block = block.strip()
            if not block:
                continue
            # восстанавливаем строку с # id:
            block = "# id: " + block

            match = re.search(r"# id:\s*.*?(\d+)", block)
            if match:
                id_num = int(match.group(1))
                entries.append((id_num, block))

# сортируем по id
entries.sort(key=lambda x: x[0])

with open(output_file, "w", encoding="utf-8") as out:
    for _, block in entries:
        out.write(block.strip() + "\n\n")

print(f"Готово! Итоговый файл сохранён: {output_file}")
# Out:
# Готово! Итоговый файл сохранён: /content/drive/MyDrive/Курсовая_3_курс/Голосовые/Текст/Объединенный_по_id_2.txt
